# %%
import aiohttp
import asyncio
import requests
import time
import pandas as pd

class Logger():
    def __init__(self) -> None:
        self.t0 = time.time()
        self.tl = self.t0

    def __call__(self, msg: str, *args):
        tn = time.time()
        ts = f"{tn - self.t0:9.4f}s"
        if (tn - self.tl) < 0.1:
            ds = "<0.1s"
        else:
            ds = f"{tn - self.tl:4.1f}s"
        self.tl = tn

        msg = f"{ts} ({ds}): {' '.join([msg, *[str(a) for a in args]])}"
        print(msg)

async def fetch(sess, url, log):
    async with sess.get(url) as req:
        if req.status != 200:
            req.raise_for_status()
        log(f"Read {url}.")
        return await req.text()

async def fetch_all(sess, urls, log):
    tasks = []
    for url in urls:
        task = asyncio.create_task(fetch(sess, url, log))
        tasks.append(task)
    res = await asyncio.gather(*tasks)
    return res

async def read_json_from_hdruk_api(endpoints):
    URL = "https://phenotypes.healthdatagateway.org/api/v1/public"
    urls =[f"{URL}/{ep}/?format=json" for ep in endpoints]
    
    log = Logger()
    log(f"Reading {len(urls)} URLs...")

    async with aiohttp.ClientSession() as sess:
        responses = await fetch_all(sess, urls, log)
    
    data = {ep: pd.read_json(res) for ep, res in zip(endpoints, responses)}
    log("Finished reading.")
    
    return data

# %%
resources = [
    "phenotypes",
    "concepts",
    "coding-systems",
    "data-sources",
    "tags",
    "collections",
]
data = await read_json_from_hdruk_api(resources)
# Out:
#    0.0000s (<0.1s): Reading 6 URLs...
#    0.4706s ( 0.5s): Read https://phenotypes.healthdatagateway.org/api/v1/public/tags/?format=json.
#    0.4757s (<0.1s): Read https://phenotypes.healthdatagateway.org/api/v1/public/coding-systems/?format=json.
#    0.4907s (<0.1s): Read https://phenotypes.healthdatagateway.org/api/v1/public/collections/?format=json.
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# Cell In [11], line 9
#       1 resources = [
#       2     "phenotypes",
#       3     "concepts",
#    (...)
#       7     "collections",
#       8 ]
# ----> 9 data = await read_json_from_hdruk_api(resources)
#
# Cell In [9], line 47, in read_json_from_hdruk_api(endpoints)
#      44 log(f"Reading {len(urls)} URLs...")
#      46 async with aiohttp.ClientSession() as sess:
# ---> 47     responses = await fetch_all(sess, urls, log)
#      49 data = {ep: pd.read_json(res) for ep, res in zip(endpoints, responses)}
#      50 log("Finished reading.")
#
# Cell In [9], line 36, in fetch_all(sess, urls, log)
#      34     task = asyncio.create_task(fetch(sess, url, log))
#      35     tasks.append(task)
# ---> 36 res = await asyncio.gather(*tasks)
#      37 return res
#
# Cell In [9], line 27, in fetch(sess, url, log)
#      25 async with sess.get(url) as req:
#      26     if req.status != 200:
# ---> 27         req.raise_for_status()
#      28     log(f"Read {url}.")
#      29     return await req.text()
#
# File ~/venv/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1005, in ClientResponse.raise_for_status(self)
#    1003 assert self.reason is not None
#    1004 self.release()
# -> 1005 raise ClientResponseError(
#    1006     self.request_info,
#    1007     self.history,
#    1008     status=self.status,
#    1009     message=self.reason,
#    1010     headers=self.headers,
#    1011 )
#
# ClientResponseError: 500, message='Internal Server Error', url=URL('https://phenotypes.healthdatagateway.org/api/v1/public/phenotypes/?format=json')

# %%
df = data["phenotypes"]
df.head()
# Out:
#   phenotype_id  version_id          phenotype_name                 type  \
# 0          PH1           2      COVID-19 infection  Disease or Syndrome
# 1          PH2           4                 Anxiety  Disease or Syndrome
# 2          PH3           6              Depression  Disease or Syndrome
# 3          PH4           8               Self Harm  Disease or Syndrome
# 4          PH5        1509  Cardiovascular Disease  Disease or Syndrome
#
#                                               author          owner tags  \
# 0                        BHF CVD COVID UK Consortium  ieuan.scanlon   []
# 1  Matthew J Carr, Sarah Steeg, Roger T Webb, Nav...  ieuan.scanlon   []
# 2  Matthew J Carr, Sarah Steeg, Roger T Webb, Nav...  ieuan.scanlon   []
# 3  Matthew J Carr, Sarah Steeg, Roger T Webb, Nav...  ieuan.scanlon   []
# 4  Ellie Paige, Jessica Barret, David Stevens, Ru...  ieuan.scanlon   []
#
#                                          collections  \
# 0  [{'description': 'BHF Data Science Centre', 'i...
# 1  [{'description': 'Phenotype Library', 'id': 18...
# 2  [{'description': 'Phenotype Library', 'id': 18...
# 3  [{'description': 'Phenotype Library', 'id': 18...
# 4  [{'description': 'Phenotype Library', 'id': 18...
#
#                               clinical_terminologies  \
# 0  [{'name': 'ICD10 codes', 'id': 4}, {'name': 'S...
# 1               [{'name': 'Read codes v2', 'id': 5}]
# 2               [{'name': 'Read codes v2', 'id': 5}]
# 3               [{'name': 'Read codes v2', 'id': 5}]
# 4               [{'name': 'Read codes v2', 'id': 5}]
#
#                                         data_sources  \
# 0  [{'id': 1, 'name': 'GPES Data for Pandemic Pla...
# 1  [{'id': 6, 'name': 'CPRD Aurum', 'url': 'https...
# 2  [{'id': 6, 'name': 'CPRD Aurum', 'url': 'https...
# 3  [{'id': 6, 'name': 'CPRD Aurum', 'url': 'https...
# 4  [{'id': 5, 'name': 'CPRD GOLD', 'url': 'https:...
#
#                                             versions
# 0  [{'version_id': 2, 'version_name': 'COVID-19 i...
# 1  [{'version_id': 4, 'version_name': 'Anxiety', ...
# 2  [{'version_id': 6, 'version_name': 'Depression...
# 3  [{'version_id': 8, 'version_name': 'Self Harm'...
# 4  [{'version_id': 1509, 'version_name': 'Cardiov...

# %%
details = []
log = Logger()
log("Reading from API...")
for ph_id in df.phenotype_id:
    data = requests.get(f"{URL}/phenotypes/{ph_id}/detail/?format=json").content
    details.append(pd.read_json(data.decode('utf-8')).iloc[0])
    log(f"Read {ph_id} details.")
# Out:
#    0.0000s (<0.1s): Reading from API...
#    0.6237s (0.6s): Read PH1 details.
#    1.3838s (0.8s): Read PH2 details.
#    2.2563s (0.9s): Read PH3 details.
#    4.5496s (2.3s): Read PH4 details.
#    5.9107s (1.4s): Read PH5 details.
#    7.1803s (1.3s): Read PH6 details.
#    7.7271s (0.5s): Read PH7 details.
#    8.8062s (1.1s): Read PH8 details.
#    9.6378s (0.8s): Read PH9 details.
#   10.0980s (0.5s): Read PH10 details.
#   11.2768s (1.2s): Read PH11 details.
#   12.9636s (1.7s): Read PH12 details.
#   13.6868s (0.7s): Read PH13 details.
#   14.4874s (0.8s): Read PH14 details.
#   16.0500s (1.6s): Read PH15 details.
#   16.6812s (0.6s): Read PH16 details.
#   17.1131s (0.4s): Read PH17 details.
#   18.3713s (1.3s): Read PH18 details.
#   18.9537s (0.6s): Read PH19 details.
#   19.6792s (0.7s): Read PH20 details.
#   20.1734s (0.5s): Read PH21 details.
#   20.6616s (0.5s): Read PH22 details.
#   21.1609s (0.5s): Read PH23 details.
#   21.6600s (0.5s): Read PH24 details.
#   22.1639s (0.5s): Read PH25 details.
#   22.6474s (0.5s): Read PH26 details.
#   23.1275s (0.5s): Read PH27 details.
#   23.6696s (0.5s): Read PH28 details.
#   24.4606s (0.8s): Read PH29 details.
#   27.8661s (3.4s): Read PH30 details.
#   28.3664s (0.5s): Read PH31 details.
#   28.8807s (0.5s): Read PH32 details.
#   29.5104s (0.6s): Read PH33 details.
#   30.1717s (0.7s): Read PH34 details.
#   30.8347s (0.7s): Read PH35 details.
#   31.5215s (0.7s): Read PH36 details.
#   32.0334s (0.5s): Read PH37 details.
#   33.2078s (1.2s): Read PH38 details.
#   33.7996s (0.6s): Read PH39 details.
#   34.4731s (0.7s): Read PH40 details.
#   35.3359s (0.9s): Read PH41 details.
#   35.7896s (0.5s): Read PH42 details.
#   36.6675s (0.9s): Read PH43 details.
#   37.3896s (0.7s): Read PH44 details.
#   38.7344s (1.3s): Read PH45 details.
#   39.3958s (0.7s): Read PH46 details.
#   40.7711s (1.4s): Read PH47 details.
#   41.6062s (0.8s): Read PH48 details.
#   42.2282s (0.6s): Read PH49 details.
#   42.6969s (0.5s): Read PH50 details.
#   43.1344s (0.4s): Read PH51 details.
#   43.6627s (0.5s): Read PH52 details.
#   44.2844s (0.6s): Read PH53 details.
#   44.9544s (0.7s): Read PH54 details.
#   45.6327s (0.7s): Read PH55 details.
#   46.4127s (0.8s): Read PH56 details.
#   47.0261s (0.6s): Read PH57 details.
#   47.7710s (0.7s): Read PH58 details.
#   48.1983s (0.4s): Read PH59 details.
#   48.8660s (0.7s): Read PH60 details.
#   49.4824s (0.6s): Read PH61 details.
#   50.0961s (0.6s): Read PH62 details.
#   50.7781s (0.7s): Read PH63 details.
#   52.2920s (1.5s): Read PH64 details.
#   53.5647s (1.3s): Read PH65 details.
#   54.1911s (0.6s): Read PH66 details.
#   54.7824s (0.6s): Read PH67 details.
#   55.3730s (0.6s): Read PH68 details.
#   56.0392s (0.7s): Read PH69 details.
#   57.0701s (1.0s): Read PH70 details.
#   57.7004s (0.6s): Read PH71 details.
#   58.2193s (0.5s): Read PH72 details.
#   58.8413s (0.6s): Read PH73 details.
#   59.4276s (0.6s): Read PH74 details.
#   60.0673s (0.6s): Read PH75 details.
#   60.6979s (0.6s): Read PH76 details.
#   61.3381s (0.6s): Read PH77 details.
#   62.5477s (1.2s): Read PH78 details.
#   64.0415s (1.5s): Read PH79 details.
#   65.7036s (1.7s): Read PH80 details.
#   66.8683s (1.2s): Read PH81 details.
#   67.4110s (0.5s): Read PH82 details.
#   68.2139s (0.8s): Read PH83 details.
#   68.8333s (0.6s): Read PH84 details.
#   69.6586s (0.8s): Read PH85 details.
#   70.2991s (0.6s): Read PH86 details.
#   72.0554s (1.8s): Read PH87 details.
#   72.7881s (0.7s): Read PH88 details.
#   73.5984s (0.8s): Read PH89 details.
#   74.1967s (0.6s): Read PH90 details.
#   74.8825s (0.7s): Read PH91 details.
#   75.4682s (0.6s): Read PH92 details.
#   76.1387s (0.7s): Read PH93 details.
#   77.3854s (1.2s): Read PH94 details.
#   78.2489s (0.9s): Read PH95 details.
#   78.8620s (0.6s): Read PH96 details.
#   79.5213s (0.7s): Read PH97 details.
#   80.1270s (0.6s): Read PH98 details.
#   80.7849s (0.7s): Read PH99 details.
#   81.3084s (0.5s): Read PH100 details.
#   82.0433s (0.7s): Read PH101 details.
#   82.9393s (0.9s): Read PH102 details.
#   83.7969s (0.9s): Read PH103 details.
#   84.8025s (1.0s): Read PH104 details.
#   85.6518s (0.8s): Read PH105 details.
#   86.5371s (0.9s): Read PH106 details.
#   87.1169s (0.6s): Read PH107 details.
#   87.7962s (0.7s): Read PH108 details.
#   88.6429s (0.8s): Read PH109 details.
#   89.4089s (0.8s): Read PH110 details.
#   90.0235s (0.6s): Read PH111 details.
#   90.8275s (0.8s): Read PH112 details.
#   91.4599s (0.6s): Read PH113 details.
#   92.0793s (0.6s): Read PH114 details.
#   92.6734s (0.6s): Read PH115 details.
#   93.4816s (0.8s): Read PH116 details.
#   94.3786s (0.9s): Read PH117 details.
#   94.9974s (0.6s): Read PH118 details.
#   95.5849s (0.6s): Read PH119 details.
#   96.4443s (0.9s): Read PH120 details.
#   97.2446s (0.8s): Read PH121 details.
#   97.9315s (0.7s): Read PH122 details.
#   98.5993s (0.7s): Read PH123 details.
#   99.3773s (0.8s): Read PH124 details.
#   99.9670s (0.6s): Read PH125 details.
#  101.0195s (1.1s): Read PH126 details.
#  101.5854s (0.6s): Read PH127 details.
#  102.1882s (0.6s): Read PH128 details.
#  103.0528s (0.9s): Read PH129 details.
#  103.7003s (0.6s): Read PH130 details.
#  104.8904s (1.2s): Read PH131 details.
#  105.7633s (0.9s): Read PH132 details.
#  106.4089s (0.6s): Read PH133 details.
#  107.1227s (0.7s): Read PH134 details.
#  108.0107s (0.9s): Read PH135 details.
#  108.6684s (0.7s): Read PH136 details.
#  109.5127s (0.8s): Read PH137 details.
#  110.2736s (0.8s): Read PH138 details.
#  111.0778s (0.8s): Read PH139 details.
#  111.9980s (0.9s): Read PH140 details.
#  112.6338s (0.6s): Read PH141 details.
#  113.4833s (0.8s): Read PH142 details.
#  114.7331s (1.2s): Read PH143 details.
#  115.4973s (0.8s): Read PH144 details.
#  116.1099s (0.6s): Read PH145 details.
#  117.4730s (1.4s): Read PH146 details.
#  118.3098s (0.8s): Read PH147 details.
#  119.2698s (1.0s): Read PH148 details.
#  120.5358s (1.3s): Read PH149 details.
#  122.0408s (1.5s): Read PH150 details.
#  123.0101s (1.0s): Read PH151 details.
#  124.3549s (1.3s): Read PH152 details.
#  124.9394s (0.6s): Read PH153 details.
#  125.8378s (0.9s): Read PH154 details.
#  126.7590s (0.9s): Read PH155 details.
#  127.4082s (0.6s): Read PH156 details.
#  128.0490s (0.6s): Read PH157 details.
#  128.5987s (0.5s): Read PH158 details.
#  129.2453s (0.6s): Read PH159 details.
#  129.7861s (0.5s): Read PH160 details.
#  130.4348s (0.6s): Read PH161 details.
#  131.3068s (0.9s): Read PH162 details.
#  131.9058s (0.6s): Read PH163 details.
#  133.5209s (1.6s): Read PH164 details.
#  134.7950s (1.3s): Read PH165 details.
#  135.3683s (0.6s): Read PH166 details.
#  135.9072s (0.5s): Read PH167 details.
#  136.5138s (0.6s): Read PH168 details.
#  137.5980s (1.1s): Read PH169 details.
#  138.4008s (0.8s): Read PH170 details.
#  139.1605s (0.8s): Read PH171 details.
#  139.7800s (0.6s): Read PH172 details.
#  141.0422s (1.3s): Read PH173 details.
#  141.9324s (0.9s): Read PH174 details.
#  142.6511s (0.7s): Read PH175 details.
#  143.5695s (0.9s): Read PH176 details.
#  144.3921s (0.8s): Read PH177 details.
#  145.2658s (0.9s): Read PH178 details.
#  145.7678s (0.5s): Read PH179 details.
#  147.8300s (2.1s): Read PH180 details.
#  148.7178s (0.9s): Read PH181 details.
#  149.7011s (1.0s): Read PH182 details.
#  150.3364s (0.6s): Read PH183 details.
#  151.2315s (0.9s): Read PH184 details.
#  151.8520s (0.6s): Read PH185 details.
#  152.8183s (1.0s): Read PH186 details.
#  153.5468s (0.7s): Read PH187 details.
#  154.1494s (0.6s): Read PH188 details.
#  155.2215s (1.1s): Read PH189 details.
#  155.9044s (0.7s): Read PH190 details.
#  156.8059s (0.9s): Read PH191 details.
#  157.7879s (1.0s): Read PH192 details.
#  159.3615s (1.6s): Read PH193 details.
#  159.9435s (0.6s): Read PH194 details.
#  160.7873s (0.8s): Read PH195 details.
#  161.4227s (0.6s): Read PH196 details.
#  162.3072s (0.9s): Read PH197 details.
#  162.9704s (0.7s): Read PH198 details.
#  164.2852s (1.3s): Read PH199 details.
#  164.9841s (0.7s): Read PH200 details.
#  165.5282s (0.5s): Read PH201 details.
#  166.1495s (0.6s): Read PH202 details.
#  166.9851s (0.8s): Read PH203 details.
#  167.5846s (0.6s): Read PH204 details.
#  168.2069s (0.6s): Read PH205 details.
#  168.8020s (0.6s): Read PH206 details.
#  169.4910s (0.7s): Read PH207 details.
#  170.1030s (0.6s): Read PH208 details.
#  170.6328s (0.5s): Read PH209 details.
#  171.2989s (0.7s): Read PH210 details.
#  172.0057s (0.7s): Read PH211 details.
#  172.6521s (0.6s): Read PH212 details.
#  173.2595s (0.6s): Read PH213 details.
#  173.8104s (0.6s): Read PH214 details.
#  174.7707s (1.0s): Read PH215 details.
#  175.4909s (0.7s): Read PH216 details.
#  176.3695s (0.9s): Read PH217 details.
#  177.2630s (0.9s): Read PH218 details.
#  177.9509s (0.7s): Read PH219 details.
#  178.6113s (0.7s): Read PH220 details.
#  179.5534s (0.9s): Read PH221 details.
#  180.3289s (0.8s): Read PH222 details.
#  180.9838s (0.7s): Read PH223 details.
#  181.6646s (0.7s): Read PH224 details.
#  182.5455s (0.9s): Read PH225 details.
#  183.4746s (0.9s): Read PH226 details.
#  184.0067s (0.5s): Read PH227 details.
#  184.9711s (1.0s): Read PH228 details.
#  185.5568s (0.6s): Read PH229 details.
#  186.3220s (0.8s): Read PH230 details.
#  187.4365s (1.1s): Read PH231 details.
#  188.1285s (0.7s): Read PH232 details.
#  188.6957s (0.6s): Read PH233 details.
#  189.3168s (0.6s): Read PH234 details.
#  190.7897s (1.5s): Read PH235 details.
#  192.6288s (1.8s): Read PH236 details.
#  193.8390s (1.2s): Read PH237 details.
#  194.5643s (0.7s): Read PH238 details.
#  195.4148s (0.9s): Read PH239 details.
#  196.0902s (0.7s): Read PH240 details.
#  196.7054s (0.6s): Read PH241 details.
#  197.3378s (0.6s): Read PH242 details.
#  197.9513s (0.6s): Read PH243 details.
#  198.5599s (0.6s): Read PH244 details.
#  199.4748s (0.9s): Read PH245 details.
#  200.1553s (0.7s): Read PH246 details.
#  200.8464s (0.7s): Read PH247 details.
#  201.5142s (0.7s): Read PH248 details.
#  202.8186s (1.3s): Read PH249 details.
#  203.6059s (0.8s): Read PH250 details.
#  204.6903s (1.1s): Read PH251 details.
#  205.5537s (0.9s): Read PH252 details.
#  206.2130s (0.7s): Read PH253 details.
#  206.8686s (0.7s): Read PH254 details.
#  207.5274s (0.7s): Read PH255 details.
#  208.3566s (0.8s): Read PH256 details.
#  209.4062s (1.0s): Read PH257 details.
#  210.0125s (0.6s): Read PH258 details.
#  210.6340s (0.6s): Read PH259 details.
#  211.2511s (0.6s): Read PH260 details.
#  212.6085s (1.4s): Read PH261 details.
#  215.0426s (2.4s): Read PH262 details.
#  215.6596s (0.6s): Read PH263 details.
#  216.3104s (0.7s): Read PH264 details.
#  216.9106s (0.6s): Read PH265 details.
#  218.0423s (1.1s): Read PH266 details.
#  218.7722s (0.7s): Read PH267 details.
#  219.4564s (0.7s): Read PH268 details.
#  220.1197s (0.7s): Read PH269 details.
#  220.6906s (0.6s): Read PH270 details.
#  221.3861s (0.7s): Read PH271 details.
#  221.9891s (0.6s): Read PH272 details.
#  222.8097s (0.8s): Read PH273 details.
#  223.5553s (0.7s): Read PH274 details.
#  224.1320s (0.6s): Read PH275 details.
#  224.7800s (0.6s): Read PH276 details.
#  225.4148s (0.6s): Read PH277 details.
#  226.2324s (0.8s): Read PH278 details.
#  226.8557s (0.6s): Read PH279 details.
#  227.7209s (0.9s): Read PH280 details.
#  228.4286s (0.7s): Read PH281 details.
#  229.4189s (1.0s): Read PH282 details.
#  230.0516s (0.6s): Read PH283 details.
#  230.7302s (0.7s): Read PH284 details.
#  232.0559s (1.3s): Read PH285 details.
#  232.8149s (0.8s): Read PH286 details.
#  233.5201s (0.7s): Read PH287 details.
#  234.2173s (0.7s): Read PH288 details.
#  235.0833s (0.9s): Read PH289 details.
#  235.6344s (0.6s): Read PH290 details.
#  236.2227s (0.6s): Read PH291 details.
#  236.8453s (0.6s): Read PH292 details.
#  237.4612s (0.6s): Read PH293 details.
#  238.0365s (0.6s): Read PH294 details.
#  238.6448s (0.6s): Read PH295 details.
#  239.2944s (0.6s): Read PH296 details.
#  240.2413s (0.9s): Read PH297 details.
#  240.8724s (0.6s): Read PH298 details.
#  241.4758s (0.6s): Read PH299 details.
#  242.0801s (0.6s): Read PH300 details.
#  242.6454s (0.6s): Read PH301 details.
#  243.3099s (0.7s): Read PH302 details.
#  243.8676s (0.6s): Read PH303 details.
#  244.5067s (0.6s): Read PH304 details.
#  245.1066s (0.6s): Read PH305 details.
#  245.8042s (0.7s): Read PH306 details.
#  246.4280s (0.6s): Read PH307 details.
#  247.0019s (0.6s): Read PH308 details.
#  247.6343s (0.6s): Read PH309 details.
#  248.7064s (1.1s): Read PH310 details.
#  249.3670s (0.7s): Read PH311 details.
#  250.0204s (0.7s): Read PH312 details.
#  250.6852s (0.7s): Read PH313 details.
#  251.6214s (0.9s): Read PH314 details.
#  252.8870s (1.3s): Read PH315 details.
#  253.4931s (0.6s): Read PH316 details.
#  256.1508s (2.7s): Read PH317 details.
#  256.7984s (0.6s): Read PH318 details.
#  257.4215s (0.6s): Read PH319 details.
#  258.0883s (0.7s): Read PH320 details.
#  258.7344s (0.6s): Read PH321 details.
#  259.7665s (1.0s): Read PH322 details.
#  260.4094s (0.6s): Read PH323 details.
#  261.0292s (0.6s): Read PH324 details.
#  261.6169s (0.6s): Read PH325 details.
#  262.2825s (0.7s): Read PH326 details.
#  263.6618s (1.4s): Read PH327 details.
#  264.4324s (0.8s): Read PH328 details.
#  265.0914s (0.7s): Read PH329 details.
#  265.7816s (0.7s): Read PH330 details.
#  267.1734s (1.4s): Read PH331 details.
#  267.8917s (0.7s): Read PH332 details.
#  268.4061s (0.5s): Read PH333 details.
#  269.2514s (0.8s): Read PH334 details.
#  269.9725s (0.7s): Read PH335 details.
#  270.5763s (0.6s): Read PH336 details.
#  271.2722s (0.7s): Read PH337 details.
#  272.1914s (0.9s): Read PH338 details.
#  272.8083s (0.6s): Read PH339 details.
#  277.1056s (4.3s): Read PH340 details.
#  277.8302s (0.7s): Read PH341 details.
#  278.3576s (0.5s): Read PH342 details.
#  280.4233s (2.1s): Read PH343 details.
#  281.0853s (0.7s): Read PH344 details.
#  281.6147s (0.5s): Read PH345 details.
#  282.2418s (0.6s): Read PH346 details.
#  282.7598s (0.5s): Read PH347 details.
#  287.5428s (4.8s): Read PH348 details.
#  288.1977s (0.7s): Read PH349 details.
#  288.7613s (0.6s): Read PH350 details.
#  289.2236s (0.5s): Read PH351 details.
#  289.7287s (0.5s): Read PH352 details.
#  290.2488s (0.5s): Read PH353 details.
#  290.8244s (0.6s): Read PH354 details.
#  291.3705s (0.5s): Read PH355 details.
#  291.9783s (0.6s): Read PH356 details.
#  292.6781s (0.7s): Read PH357 details.
#  293.2294s (0.6s): Read PH358 details.
#  294.0226s (0.8s): Read PH359 details.
#  295.2951s (1.3s): Read PH360 details.
#  296.6015s (1.3s): Read PH361 details.
#  297.2052s (0.6s): Read PH362 details.
#  297.8186s (0.6s): Read PH363 details.
#  298.9392s (1.1s): Read PH364 details.
#  299.8395s (0.9s): Read PH365 details.
#  301.0000s (1.2s): Read PH366 details.
#  302.1945s (1.2s): Read PH367 details.
#  302.9961s (0.8s): Read PH368 details.
#  303.8180s (0.8s): Read PH369 details.
#  304.5193s (0.7s): Read PH370 details.
#  305.2188s (0.7s): Read PH371 details.
#  305.9937s (0.8s): Read PH372 details.
#  306.7777s (0.8s): Read PH373 details.
#  308.8551s (2.1s): Read PH374 details.
#  310.6526s (1.8s): Read PH375 details.
#  311.2436s (0.6s): Read PH376 details.
#  311.8095s (0.6s): Read PH377 details.
#  312.8990s (1.1s): Read PH378 details.
#  313.9852s (1.1s): Read PH379 details.
#  315.7649s (1.8s): Read PH380 details.
#  317.5527s (1.8s): Read PH381 details.
#  318.3735s (0.8s): Read PH382 details.
#  319.1768s (0.8s): Read PH383 details.
#  319.9144s (0.7s): Read PH384 details.
#  320.6251s (0.7s): Read PH385 details.
#  321.6128s (1.0s): Read PH386 details.
#  322.5819s (1.0s): Read PH387 details.
#  323.2150s (0.6s): Read PH388 details.
#  324.0056s (0.8s): Read PH389 details.
#  325.1962s (1.2s): Read PH390 details.
#  326.4113s (1.2s): Read PH391 details.
#  327.6210s (1.2s): Read PH392 details.
#  328.2282s (0.6s): Read PH393 details.
#  329.0416s (0.8s): Read PH394 details.
#  329.8449s (0.8s): Read PH395 details.
#  330.8711s (1.0s): Read PH396 details.
#  331.8654s (1.0s): Read PH397 details.
#  333.1070s (1.2s): Read PH398 details.
#  334.2706s (1.2s): Read PH399 details.
#  337.9315s (3.7s): Read PH400 details.
#  339.6513s (1.7s): Read PH401 details.
#  340.2655s (0.6s): Read PH402 details.
#  340.9991s (0.7s): Read PH403 details.
#  342.0229s (1.0s): Read PH404 details.
#  344.5112s (2.5s): Read PH405 details.
#  345.3403s (0.8s): Read PH406 details.
#  347.1226s (1.8s): Read PH407 details.
#  347.7703s (0.6s): Read PH408 details.
#  348.4281s (0.7s): Read PH409 details.
#  349.2085s (0.8s): Read PH410 details.
#  349.8074s (0.6s): Read PH411 details.
#  350.5508s (0.7s): Read PH412 details.
#  351.0638s (0.5s): Read PH413 details.
#  352.3943s (1.3s): Read PH414 details.
#  353.3123s (0.9s): Read PH415 details.
#  353.8588s (0.5s): Read PH416 details.
#  354.7061s (0.8s): Read PH417 details.
#  355.6269s (0.9s): Read PH418 details.
#  357.2980s (1.7s): Read PH419 details.
#  358.5213s (1.2s): Read PH420 details.
#  359.0835s (0.6s): Read PH421 details.
#  360.0266s (0.9s): Read PH422 details.
#  360.6577s (0.6s): Read PH423 details.
#  361.2551s (0.6s): Read PH424 details.
#  361.8885s (0.6s): Read PH425 details.
#  362.4323s (0.5s): Read PH426 details.
#  363.0097s (0.6s): Read PH427 details.
#  363.6332s (0.6s): Read PH428 details.
#  364.2355s (0.6s): Read PH429 details.
#  364.8844s (0.6s): Read PH430 details.
#  365.6407s (0.8s): Read PH431 details.
#  366.7856s (1.1s): Read PH432 details.
#  367.2978s (0.5s): Read PH433 details.
#  367.8301s (0.5s): Read PH434 details.
#  368.4024s (0.6s): Read PH435 details.
#  369.2351s (0.8s): Read PH436 details.
#  369.8831s (0.6s): Read PH437 details.
#  370.6980s (0.8s): Read PH438 details.
#  373.4035s (2.7s): Read PH439 details.
#  374.0204s (0.6s): Read PH440 details.
#  374.5878s (0.6s): Read PH441 details.
#  375.3716s (0.8s): Read PH442 details.
#  375.8631s (0.5s): Read PH443 details.
#  376.6241s (0.8s): Read PH444 details.
#  377.3735s (0.7s): Read PH445 details.
#  377.9261s (0.6s): Read PH446 details.
#  378.5495s (0.6s): Read PH447 details.
#  379.0750s (0.5s): Read PH448 details.
#  379.5896s (0.5s): Read PH449 details.
#  380.1523s (0.6s): Read PH450 details.
#  380.9253s (0.8s): Read PH451 details.
#  388.4437s (7.5s): Read PH452 details.
#  389.1043s (0.7s): Read PH453 details.
#  390.4299s (1.3s): Read PH454 details.
#  392.2567s (1.8s): Read PH455 details.
#  393.2135s (1.0s): Read PH456 details.
#  394.0334s (0.8s): Read PH457 details.
#  394.8428s (0.8s): Read PH458 details.
#  395.4092s (0.6s): Read PH459 details.
#  395.9481s (0.5s): Read PH460 details.
#  396.7252s (0.8s): Read PH461 details.
#  397.3652s (0.6s): Read PH462 details.
#  397.9447s (0.6s): Read PH463 details.
#  399.3251s (1.4s): Read PH464 details.
#  399.9370s (0.6s): Read PH465 details.
#  400.4965s (0.6s): Read PH466 details.
#  401.3958s (0.9s): Read PH467 details.
#  401.8860s (0.5s): Read PH468 details.
#  402.4093s (0.5s): Read PH469 details.
#  402.9456s (0.5s): Read PH470 details.
#  403.7027s (0.8s): Read PH471 details.
#  405.1392s (1.4s): Read PH472 details.
#  405.7617s (0.6s): Read PH473 details.
#  406.5229s (0.8s): Read PH474 details.
#  407.0494s (0.5s): Read PH475 details.
#  407.6042s (0.6s): Read PH476 details.
#  408.0970s (0.5s): Read PH477 details.
#  408.7833s (0.7s): Read PH478 details.
#  409.4228s (0.6s): Read PH479 details.
#  410.3923s (1.0s): Read PH480 details.
#  411.1906s (0.8s): Read PH481 details.
#  411.7312s (0.5s): Read PH482 details.
#  412.4776s (0.7s): Read PH483 details.
#  413.2427s (0.8s): Read PH484 details.
#  413.7916s (0.5s): Read PH485 details.
#  417.3235s (3.5s): Read PH486 details.
#  418.5634s (1.2s): Read PH487 details.
#  419.2743s (0.7s): Read PH488 details.
#  420.0475s (0.8s): Read PH489 details.
#  421.6814s (1.6s): Read PH490 details.
#  423.2169s (1.5s): Read PH491 details.
#  423.7211s (0.5s): Read PH492 details.
#  424.5114s (0.8s): Read PH493 details.
#  425.0888s (0.6s): Read PH494 details.
#  425.8217s (0.7s): Read PH495 details.
#  426.4929s (0.7s): Read PH496 details.
#  427.1593s (0.7s): Read PH497 details.
#  429.0515s (1.9s): Read PH498 details.
#  430.0131s (1.0s): Read PH499 details.
#  430.7538s (0.7s): Read PH500 details.
#  432.0259s (1.3s): Read PH501 details.
#  432.6858s (0.7s): Read PH502 details.
#  434.3502s (1.7s): Read PH503 details.
#  438.0168s (3.7s): Read PH504 details.
#  441.2498s (3.2s): Read PH505 details.
#  442.1778s (0.9s): Read PH506 details.
#  442.8490s (0.7s): Read PH507 details.
#  443.4908s (0.6s): Read PH508 details.
#  444.1855s (0.7s): Read PH509 details.
#  444.8989s (0.7s): Read PH510 details.
#  445.4498s (0.6s): Read PH511 details.
#  446.1621s (0.7s): Read PH512 details.
#  446.8723s (0.7s): Read PH513 details.
#  447.6404s (0.8s): Read PH514 details.
#  448.3953s (0.8s): Read PH515 details.
#  449.1508s (0.8s): Read PH516 details.
#  449.9874s (0.8s): Read PH517 details.
#  451.2041s (1.2s): Read PH518 details.
#  452.4356s (1.2s): Read PH519 details.
#  454.0694s (1.6s): Read PH520 details.
#  455.2804s (1.2s): Read PH521 details.
#  456.0642s (0.8s): Read PH522 details.
#  456.6015s (0.5s): Read PH523 details.
#  457.4536s (0.9s): Read PH524 details.
#  458.8186s (1.4s): Read PH525 details.
#  459.5910s (0.8s): Read PH526 details.
#  460.0940s (0.5s): Read PH527 details.
#  460.6029s (0.5s): Read PH528 details.
#  461.1547s (0.6s): Read PH529 details.
#  461.7336s (0.6s): Read PH530 details.
#  462.3397s (0.6s): Read PH531 details.
#  463.2795s (0.9s): Read PH532 details.
#  464.1129s (0.8s): Read PH533 details.
#  464.8164s (0.7s): Read PH534 details.
#  465.4132s (0.6s): Read PH535 details.
#  466.0011s (0.6s): Read PH536 details.
#  466.5451s (0.5s): Read PH537 details.
#  467.7144s (1.2s): Read PH538 details.
#  468.4241s (0.7s): Read PH539 details.
#  469.2385s (0.8s): Read PH540 details.
#  469.8095s (0.6s): Read PH541 details.
#  470.4002s (0.6s): Read PH542 details.
#  471.2341s (0.8s): Read PH543 details.
#  472.0893s (0.9s): Read PH544 details.
#  472.5926s (0.5s): Read PH545 details.
#  473.1772s (0.6s): Read PH546 details.
#  473.6963s (0.5s): Read PH547 details.
#  474.4594s (0.8s): Read PH548 details.
#  475.0154s (0.6s): Read PH549 details.
#  475.8497s (0.8s): Read PH550 details.
#  476.6814s (0.8s): Read PH551 details.
#  477.2158s (0.5s): Read PH552 details.
#  477.7724s (0.6s): Read PH553 details.
#  478.3101s (0.5s): Read PH554 details.
#  478.9676s (0.7s): Read PH555 details.
#  479.7318s (0.8s): Read PH556 details.
#  480.2493s (0.5s): Read PH557 details.
#  481.4285s (1.2s): Read PH558 details.
#  482.3397s (0.9s): Read PH559 details.
#  482.8595s (0.5s): Read PH560 details.
#  483.3616s (0.5s): Read PH561 details.
#  484.1387s (0.8s): Read PH562 details.
#  484.9767s (0.8s): Read PH563 details.
#  485.7739s (0.8s): Read PH564 details.
#  486.5735s (0.8s): Read PH565 details.
#  487.2962s (0.7s): Read PH566 details.
#  487.8122s (0.5s): Read PH567 details.
#  488.5786s (0.8s): Read PH568 details.
#  489.3716s (0.8s): Read PH569 details.
#  489.8890s (0.5s): Read PH570 details.
#  490.6614s (0.8s): Read PH571 details.
#  491.4986s (0.8s): Read PH572 details.
#  493.6647s (2.2s): Read PH573 details.
#  494.5651s (0.9s): Read PH574 details.
#  495.5351s (1.0s): Read PH575 details.
#  496.9806s (1.4s): Read PH576 details.
#  497.6693s (0.7s): Read PH577 details.
#  499.6463s (2.0s): Read PH578 details.
#  500.1952s (0.5s): Read PH579 details.
#  501.8046s (1.6s): Read PH580 details.
#  502.3495s (0.5s): Read PH581 details.
#  503.6358s (1.3s): Read PH582 details.
#  504.1437s (0.5s): Read PH583 details.
#  504.9057s (0.8s): Read PH584 details.
#  505.4600s (0.6s): Read PH585 details.
#  506.2473s (0.8s): Read PH586 details.
#  506.8172s (0.6s): Read PH587 details.
#  507.4093s (0.6s): Read PH588 details.
#  507.9018s (0.5s): Read PH589 details.
#  508.6506s (0.7s): Read PH590 details.
#  509.6401s (1.0s): Read PH591 details.
#  510.8173s (1.2s): Read PH592 details.
#  511.3098s (0.5s): Read PH593 details.
#  511.8617s (0.6s): Read PH594 details.
#  512.6821s (0.8s): Read PH595 details.
#  513.2357s (0.6s): Read PH596 details.
#  513.7477s (0.5s): Read PH597 details.
#  514.9576s (1.2s): Read PH598 details.
#  515.5297s (0.6s): Read PH599 details.
#  516.0168s (0.5s): Read PH600 details.
#  516.5017s (0.5s): Read PH601 details.
#  517.0880s (0.6s): Read PH602 details.
#  517.5963s (0.5s): Read PH603 details.
#  518.1019s (0.5s): Read PH604 details.
#  518.8555s (0.8s): Read PH605 details.
#  519.3697s (0.5s): Read PH606 details.
#  520.1545s (0.8s): Read PH607 details.
#  520.7617s (0.6s): Read PH608 details.
#  521.2748s (0.5s): Read PH609 details.
#  521.8633s (0.6s): Read PH610 details.
#  522.3781s (0.5s): Read PH611 details.
#  522.9379s (0.6s): Read PH612 details.
#  523.6248s (0.7s): Read PH613 details.
#  524.1644s (0.5s): Read PH614 details.
#  524.9131s (0.7s): Read PH615 details.
#  528.3583s (3.4s): Read PH616 details.
#  528.9789s (0.6s): Read PH617 details.
#  530.1901s (1.2s): Read PH618 details.
#  530.7843s (0.6s): Read PH619 details.
#  531.5628s (0.8s): Read PH620 details.
#  532.4672s (0.9s): Read PH621 details.
#  533.2585s (0.8s): Read PH622 details.
#  533.9016s (0.6s): Read PH623 details.
#  537.2171s (3.3s): Read PH624 details.
#  537.8636s (0.6s): Read PH625 details.
#  538.6139s (0.8s): Read PH626 details.
#  539.2777s (0.7s): Read PH627 details.
#  540.0857s (0.8s): Read PH628 details.
#  541.3610s (1.3s): Read PH629 details.
#  542.1217s (0.8s): Read PH630 details.
#  542.7469s (0.6s): Read PH631 details.
#  543.5865s (0.8s): Read PH632 details.
#  544.1747s (0.6s): Read PH633 details.
#  544.8076s (0.6s): Read PH634 details.
#  545.6935s (0.9s): Read PH635 details.
#  546.2479s (0.6s): Read PH636 details.
#  546.8710s (0.6s): Read PH637 details.
#  548.0693s (1.2s): Read PH638 details.
#  548.8320s (0.8s): Read PH639 details.
#  549.3773s (0.5s): Read PH640 details.
#  550.8711s (1.5s): Read PH641 details.
#  552.4137s (1.5s): Read PH642 details.
#  552.9208s (0.5s): Read PH643 details.
#  554.5566s (1.6s): Read PH644 details.
#  555.1039s (0.5s): Read PH645 details.
#  556.1847s (1.1s): Read PH646 details.
#  557.3616s (1.2s): Read PH647 details.
#  557.9010s (0.5s): Read PH648 details.
#  558.4221s (0.5s): Read PH649 details.
#  559.3491s (0.9s): Read PH650 details.
#  559.8559s (0.5s): Read PH651 details.
#  560.3964s (0.5s): Read PH652 details.
#  560.9085s (0.5s): Read PH653 details.
#  561.3977s (0.5s): Read PH654 details.
#  562.0177s (0.6s): Read PH655 details.
#  563.7886s (1.8s): Read PH656 details.
#  564.3228s (0.5s): Read PH657 details.
#  565.1365s (0.8s): Read PH658 details.
#  565.9042s (0.8s): Read PH659 details.
#  567.2724s (1.4s): Read PH660 details.
#  569.6859s (2.4s): Read PH661 details.
#  570.4224s (0.7s): Read PH662 details.
#  570.9945s (0.6s): Read PH663 details.
#  571.6177s (0.6s): Read PH664 details.
#  572.4585s (0.8s): Read PH665 details.
#  573.1984s (0.7s): Read PH666 details.
#  573.6847s (0.5s): Read PH667 details.
#  574.2404s (0.6s): Read PH668 details.
#  574.7634s (0.5s): Read PH669 details.
#  576.8856s (2.1s): Read PH670 details.
#  578.6341s (1.7s): Read PH671 details.
#  579.3951s (0.8s): Read PH672 details.
#  580.6739s (1.3s): Read PH673 details.
#  581.8968s (1.2s): Read PH674 details.
#  582.4398s (0.5s): Read PH675 details.
#  582.9971s (0.6s): Read PH676 details.
#  583.5718s (0.6s): Read PH677 details.
#  584.1041s (0.5s): Read PH678 details.
#  585.2573s (1.2s): Read PH679 details.
#  585.8043s (0.5s): Read PH680 details.
#  587.6435s (1.8s): Read PH681 details.
#  590.1717s (2.5s): Read PH682 details.
#  590.7689s (0.6s): Read PH683 details.
#  591.8405s (1.1s): Read PH684 details.
#  592.7067s (0.9s): Read PH685 details.
#  593.2363s (0.5s): Read PH686 details.
#  593.8226s (0.6s): Read PH687 details.
#  594.6008s (0.8s): Read PH688 details.
#  595.1593s (0.6s): Read PH689 details.
#  596.4936s (1.3s): Read PH690 details.
#  597.1981s (0.7s): Read PH691 details.
#  597.7845s (0.6s): Read PH692 details.
#  598.4504s (0.7s): Read PH693 details.
#  599.7906s (1.3s): Read PH694 details.
#  600.3778s (0.6s): Read PH695 details.
#  601.3150s (0.9s): Read PH696 details.
#  602.4957s (1.2s): Read PH697 details.
#  603.2906s (0.8s): Read PH698 details.
#  603.9691s (0.7s): Read PH699 details.
#  604.7299s (0.8s): Read PH700 details.
#  605.3209s (0.6s): Read PH701 details.
#  606.4095s (1.1s): Read PH702 details.
#  608.2716s (1.9s): Read PH703 details.
#  609.1120s (0.8s): Read PH704 details.
#  609.8447s (0.7s): Read PH705 details.
#  610.8451s (1.0s): Read PH706 details.
#  611.7775s (0.9s): Read PH707 details.
#  612.7305s (1.0s): Read PH708 details.
#  613.9784s (1.2s): Read PH709 details.
#  615.2183s (1.2s): Read PH710 details.
#  620.6763s (5.5s): Read PH711 details.
#  621.4813s (0.8s): Read PH712 details.
#  622.4738s (1.0s): Read PH713 details.
#  623.3547s (0.9s): Read PH714 details.
#  624.7680s (1.4s): Read PH715 details.
#  625.3909s (0.6s): Read PH716 details.
#  626.1696s (0.8s): Read PH717 details.
#  626.9488s (0.8s): Read PH718 details.
#  627.5450s (0.6s): Read PH719 details.
#  628.0494s (0.5s): Read PH720 details.
#  628.6283s (0.6s): Read PH721 details.
#  629.6162s (1.0s): Read PH722 details.
#  631.5725s (2.0s): Read PH723 details.
#  633.4361s (1.9s): Read PH724 details.
#  639.0346s (5.6s): Read PH725 details.
#  640.4320s (1.4s): Read PH726 details.
#  641.0462s (0.6s): Read PH727 details.
#  641.8240s (0.8s): Read PH728 details.
#  643.0263s (1.2s): Read PH729 details.
#  643.6378s (0.6s): Read PH730 details.
#  645.6028s (2.0s): Read PH731 details.
#  646.1427s (0.5s): Read PH732 details.
#  646.6587s (0.5s): Read PH733 details.
#  647.1670s (0.5s): Read PH734 details.
#  647.6868s (0.5s): Read PH735 details.
#  649.0718s (1.4s): Read PH736 details.
#  649.9396s (0.9s): Read PH737 details.
#  650.7131s (0.8s): Read PH738 details.
#  651.4480s (0.7s): Read PH739 details.
#  651.9980s (0.5s): Read PH740 details.
#  652.7411s (0.7s): Read PH741 details.
#  653.9938s (1.3s): Read PH742 details.
#  654.8286s (0.8s): Read PH743 details.
#  656.6962s (1.9s): Read PH744 details.
#  658.8897s (2.2s): Read PH745 details.
#  660.3155s (1.4s): Read PH746 details.
#  661.1625s (0.8s): Read PH747 details.
#  661.6870s (0.5s): Read PH748 details.
#  662.6918s (1.0s): Read PH749 details.
#  663.4595s (0.8s): Read PH750 details.
#  663.9833s (0.5s): Read PH751 details.
#  664.7811s (0.8s): Read PH752 details.
#  665.6614s (0.9s): Read PH753 details.
#  669.3781s (3.7s): Read PH782 details.
#  670.1965s (0.8s): Read PH783 details.
#  670.8014s (0.6s): Read PH784 details.
#  671.9772s (1.2s): Read PH785 details.
#  672.7807s (0.8s): Read PH786 details.
#  673.2934s (0.5s): Read PH787 details.
#  673.9058s (0.6s): Read PH788 details.
#  674.4422s (0.5s): Read PH789 details.
#  675.1332s (0.7s): Read PH790 details.
#  675.7790s (0.6s): Read PH791 details.
#  676.5382s (0.8s): Read PH792 details.
#  677.1364s (0.6s): Read PH793 details.
#  679.3163s (2.2s): Read PH794 details.
#  680.7548s (1.4s): Read PH795 details.
#  681.3998s (0.6s): Read PH796 details.
#  683.7924s (2.4s): Read PH797 details.
#  684.5717s (0.8s): Read PH798 details.
#  685.1448s (0.6s): Read PH799 details.
#  686.8790s (1.7s): Read PH800 details.
#  687.8072s (0.9s): Read PH801 details.
#  688.8027s (1.0s): Read PH802 details.
#  689.4382s (0.6s): Read PH803 details.
#  690.0732s (0.6s): Read PH804 details.
#  690.5733s (0.5s): Read PH805 details.
#  692.2581s (1.7s): Read PH806 details.
#  693.0927s (0.8s): Read PH807 details.
#  693.9578s (0.9s): Read PH808 details.
#  694.6322s (0.7s): Read PH809 details.
#  695.2820s (0.6s): Read PH810 details.
#  695.8030s (0.5s): Read PH811 details.
#  696.4715s (0.7s): Read PH812 details.
#  697.0347s (0.6s): Read PH813 details.
#  698.0460s (1.0s): Read PH814 details.
#  698.6656s (0.6s): Read PH815 details.
#  699.4070s (0.7s): Read PH816 details.
#  700.0556s (0.6s): Read PH817 details.
#  701.1570s (1.1s): Read PH818 details.
#  701.8378s (0.7s): Read PH819 details.
#  702.7460s (0.9s): Read PH820 details.
#  703.5257s (0.8s): Read PH821 details.
#  704.8349s (1.3s): Read PH822 details.
#  705.7109s (0.9s): Read PH823 details.
#  706.2578s (0.5s): Read PH824 details.
#  707.1698s (0.9s): Read PH825 details.
#  708.0207s (0.9s): Read PH826 details.
#  709.3476s (1.3s): Read PH827 details.
#  712.1227s (2.8s): Read PH828 details.
#  712.8793s (0.8s): Read PH829 details.
#  714.3689s (1.5s): Read PH830 details.
#  715.2235s (0.9s): Read PH831 details.
#  716.4358s (1.2s): Read PH832 details.
#  717.2156s (0.8s): Read PH833 details.
#  718.4002s (1.2s): Read PH834 details.
#  719.9207s (1.5s): Read PH835 details.
#  720.6845s (0.8s): Read PH836 details.
#  721.5882s (0.9s): Read PH837 details.
#  723.8415s (2.3s): Read PH838 details.
#  724.8126s (1.0s): Read PH839 details.
#  725.3719s (0.6s): Read PH840 details.
#  725.8390s (0.5s): Read PH841 details.
#  726.3568s (0.5s): Read PH842 details.
#  726.9009s (0.5s): Read PH843 details.
#  727.4037s (0.5s): Read PH844 details.
#  728.2602s (0.9s): Read PH845 details.
#  729.0516s (0.8s): Read PH846 details.
#  729.5956s (0.5s): Read PH847 details.
#  730.1859s (0.6s): Read PH848 details.
#  730.6270s (0.4s): Read PH849 details.
#  731.0802s (0.5s): Read PH850 details.
#  731.6048s (0.5s): Read PH851 details.
#  732.0829s (0.5s): Read PH852 details.
#  732.5714s (0.5s): Read PH853 details.
#  733.1779s (0.6s): Read PH854 details.
#  733.6164s (0.4s): Read PH855 details.
#  734.0683s (0.5s): Read PH856 details.
#  734.5276s (0.5s): Read PH857 details.
#  734.9872s (0.5s): Read PH858 details.
#  735.6798s (0.7s): Read PH859 details.
#  736.1943s (0.5s): Read PH860 details.
#  736.6932s (0.5s): Read PH861 details.
#  737.2220s (0.5s): Read PH862 details.
#  737.9676s (0.7s): Read PH863 details.
#  739.1114s (1.1s): Read PH864 details.
#  739.6297s (0.5s): Read PH865 details.
#  740.1304s (0.5s): Read PH866 details.
#  740.9820s (0.9s): Read PH867 details.
#  741.9144s (0.9s): Read PH868 details.
#  742.6049s (0.7s): Read PH869 details.
#  743.2232s (0.6s): Read PH870 details.
#  744.5406s (1.3s): Read PH871 details.
#  745.3885s (0.8s): Read PH872 details.
#  749.4906s (4.1s): Read PH873 details.
#  750.2665s (0.8s): Read PH874 details.
#  751.1830s (0.9s): Read PH875 details.
#  751.7915s (0.6s): Read PH876 details.
#  752.5994s (0.8s): Read PH877 details.
#  753.4414s (0.8s): Read PH878 details.
#  754.2986s (0.9s): Read PH879 details.
#  755.2217s (0.9s): Read PH880 details.
#  755.7852s (0.6s): Read PH881 details.
#  756.7665s (1.0s): Read PH882 details.
#  757.3793s (0.6s): Read PH883 details.
#  758.0111s (0.6s): Read PH884 details.
#  758.5974s (0.6s): Read PH885 details.
#  759.1960s (0.6s): Read PH886 details.
#  760.0103s (0.8s): Read PH887 details.
#  760.7426s (0.7s): Read PH888 details.
#  761.5426s (0.8s): Read PH889 details.
#  762.3100s (0.8s): Read PH890 details.
#  763.0915s (0.8s): Read PH891 details.
#  764.0909s (1.0s): Read PH892 details.
#  765.3096s (1.2s): Read PH893 details.
#  766.7967s (1.5s): Read PH894 details.
#  768.8558s (2.1s): Read PH895 details.
#  770.7343s (1.9s): Read PH896 details.
#  773.9461s (3.2s): Read PH897 details.
#  774.7803s (0.8s): Read PH898 details.
#  775.3707s (0.6s): Read PH899 details.
#  775.9366s (0.6s): Read PH900 details.
#  776.5246s (0.6s): Read PH901 details.
#  777.0157s (0.5s): Read PH902 details.
#  777.5935s (0.6s): Read PH903 details.
#  778.1067s (0.5s): Read PH904 details.
#  778.6861s (0.6s): Read PH905 details.
#  779.2785s (0.6s): Read PH906 details.
#  779.8138s (0.5s): Read PH907 details.
#  780.3933s (0.6s): Read PH908 details.
#  781.3827s (1.0s): Read PH909 details.
#  782.6347s (1.3s): Read PH910 details.
#  783.1871s (0.6s): Read PH911 details.
#  783.7717s (0.6s): Read PH912 details.
#  785.9732s (2.2s): Read PH913 details.
#  786.5807s (0.6s): Read PH914 details.
#  787.1099s (0.5s): Read PH915 details.
#  789.1663s (2.1s): Read PH916 details.
#  794.6578s (5.5s): Read PH917 details.
#  795.4519s (0.8s): Read PH918 details.
#  801.3413s (5.9s): Read PH919 details.
#  801.9784s (0.6s): Read PH920 details.
#  802.9816s (1.0s): Read PH921 details.
#  803.8071s (0.8s): Read PH922 details.
#  805.0674s (1.3s): Read PH923 details.
#  806.1186s (1.1s): Read PH924 details.
#  807.0703s (1.0s): Read PH925 details.
#  808.5336s (1.5s): Read PH926 details.
#  809.4127s (0.9s): Read PH927 details.
#  810.1363s (0.7s): Read PH928 details.
#  810.6356s (0.5s): Read PH929 details.
#  811.3996s (0.8s): Read PH930 details.
#  812.0467s (0.6s): Read PH931 details.
#  812.7138s (0.7s): Read PH932 details.
#  813.2030s (0.5s): Read PH933 details.
#  813.7467s (0.5s): Read PH934 details.
#  814.2815s (0.5s): Read PH935 details.
#  815.9619s (1.7s): Read PH936 details.
#  816.6233s (0.7s): Read PH937 details.
#  817.1952s (0.6s): Read PH938 details.
#  817.8833s (0.7s): Read PH939 details.
#  818.9430s (1.1s): Read PH940 details.
#  821.8785s (2.9s): Read PH941 details.
#  822.7012s (0.8s): Read PH942 details.
#  823.3191s (0.6s): Read PH943 details.
#  823.8300s (0.5s): Read PH944 details.
#  825.1326s (1.3s): Read PH945 details.
#  825.6420s (0.5s): Read PH946 details.
#  826.3566s (0.7s): Read PH947 details.
#  827.4582s (1.1s): Read PH948 details.
#  828.3987s (0.9s): Read PH949 details.
#  829.7111s (1.3s): Read PH950 details.
#  830.5678s (0.9s): Read PH951 details.
#  831.2887s (0.7s): Read PH952 details.
#  831.7942s (0.5s): Read PH953 details.
#  832.3736s (0.6s): Read PH954 details.
#  832.8694s (0.5s): Read PH955 details.
#  833.9451s (1.1s): Read PH956 details.
#  834.5335s (0.6s): Read PH957 details.
#  835.1528s (0.6s): Read PH958 details.
#  835.7083s (0.6s): Read PH959 details.
#  844.3992s (8.7s): Read PH960 details.
#  845.1698s (0.8s): Read PH961 details.
#  845.8741s (0.7s): Read PH962 details.
#  846.9406s (1.1s): Read PH963 details.
#  848.0371s (1.1s): Read PH964 details.
#  849.4104s (1.4s): Read PH965 details.
#  850.1762s (0.8s): Read PH966 details.
#  850.7248s (0.5s): Read PH967 details.
#  851.6199s (0.9s): Read PH968 details.
#  852.6041s (1.0s): Read PH969 details.
#  855.6588s (3.1s): Read PH970 details.
#  856.1871s (0.5s): Read PH971 details.
#  857.0117s (0.8s): Read PH972 details.
#  858.4497s (1.4s): Read PH973 details.
#  858.9582s (0.5s): Read PH974 details.
#  859.4482s (0.5s): Read PH975 details.
#  860.1943s (0.7s): Read PH976 details.
#  860.6780s (0.5s): Read PH977 details.
#  861.2671s (0.6s): Read PH978 details.
#  861.7573s (0.5s): Read PH979 details.
#  862.2583s (0.5s): Read PH980 details.
#  863.0395s (0.8s): Read PH981 details.
#  864.1378s (1.1s): Read PH982 details.
#  865.5129s (1.4s): Read PH983 details.
#  866.2953s (0.8s): Read PH984 details.
#  866.8810s (0.6s): Read PH985 details.
#  867.4886s (0.6s): Read PH986 details.
#  868.1037s (0.6s): Read PH987 details.
#  868.8830s (0.8s): Read PH988 details.
#  869.3853s (0.5s): Read PH989 details.
#  870.1592s (0.8s): Read PH990 details.
#  870.7932s (0.6s): Read PH991 details.
#  871.4194s (0.6s): Read PH992 details.
#  872.0411s (0.6s): Read PH993 details.
#  872.6236s (0.6s): Read PH994 details.
#  873.1793s (0.6s): Read PH995 details.
#  873.7736s (0.6s): Read PH996 details.
#  874.3121s (0.5s): Read PH997 details.
#  874.8844s (0.6s): Read PH998 details.
#  875.4934s (0.6s): Read PH999 details.
#  875.9856s (0.5s): Read PH1000 details.
#  880.9733s (5.0s): Read PH1001 details.
#  881.5411s (0.6s): Read PH1002 details.
#  882.3157s (0.8s): Read PH1003 details.
#  883.1826s (0.9s): Read PH1004 details.
#  883.8380s (0.7s): Read PH1005 details.
#  885.1432s (1.3s): Read PH1006 details.
#  885.7285s (0.6s): Read PH1007 details.
#  886.5740s (0.8s): Read PH1008 details.
#  887.1299s (0.6s): Read PH1009 details.
#  889.7550s (2.6s): Read PH1010 details.
#  890.2538s (0.5s): Read PH1011 details.
#  890.9764s (0.7s): Read PH1012 details.
#  891.8680s (0.9s): Read PH1013 details.
#  893.1949s (1.3s): Read PH1014 details.
#  893.7109s (0.5s): Read PH1015 details.
#  894.2168s (0.5s): Read PH1016 details.
#  894.9080s (0.7s): Read PH1017 details.
#  896.0967s (1.2s): Read PH1018 details.
#  896.6494s (0.6s): Read PH1019 details.
#  897.4658s (0.8s): Read PH1020 details.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [67], line 6
#       4 for ph_id in df.phenotype_id:
#       5     data = requests.get(f"{URL}/phenotypes/{ph_id}/detail/?format=json").content
# ----> 6     details.append(pd.read_json(data.decode('utf-8')).iloc[0])
#       7     log(f"Read {ph_id} details.")
#
# File ~/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/json/_json.py:612, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     609     return json_reader
#     611 with json_reader:
# --> 612     return json_reader.read()
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/json/_json.py:746, in JsonReader.read(self)
#     744         obj = self._get_object_parser(self._combine_lines(data_lines))
#     745 else:
# --> 746     obj = self._get_object_parser(self.data)
#     747 self.close()
#     748 return obj
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/json/_json.py:768, in JsonReader._get_object_parser(self, json)
#     766 obj = None
#     767 if typ == "frame":
# --> 768     obj = FrameParser(json, **kwargs).parse()
#     770 if typ == "series" or obj is None:
#     771     if not isinstance(dtype, bool):
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/json/_json.py:880, in Parser.parse(self)
#     878     self._parse_numpy()
#     879 else:
# --> 880     self._parse_no_numpy()
#     882 if self.obj is None:
#     883     return None
#
# File ~/venv/lib/python3.10/site-packages/pandas/io/json/_json.py:1132, in FrameParser._parse_no_numpy(self)
#    1129 orient = self.orient
#    1131 if orient == "columns":
# -> 1132     self.obj = DataFrame(
#    1133         loads(json, precise_float=self.precise_float), dtype=None
#    1134     )
#    1135 elif orient == "split":
#    1136     decoded = {
#    1137         str(k): v
#    1138         for k, v in loads(json, precise_float=self.precise_float).items()
#    1139     }
#
# File ~/venv/lib/python3.10/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:664, in _extract_index(data)
#     661         raise ValueError("Per-column arrays must each be 1-dimensional")
#     663 if not indexes and not raw_lengths:
# --> 664     raise ValueError("If using all scalar values, you must pass an index")
#     666 elif have_series:
#     667     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
codes = []
log = Logger()
log("Reading from API...")
for ph_id in df.phenotype_id:
    data = requests.get(f"{URL}/phenotypes/{ph_id}/export/codes/?format=json").content
    codes.append(pd.read_json(data.decode('utf-8')).iloc[0])
    log(f"Read {ph_id} code list.")
# Out:
# {'citation_requirements',
#  'concepts',
#  'definition',
#  'implementation',
#  'publication_doi',
#  'publication_link',
#  'publications',
#  'source_reference',
#  'validation_performed'}

# %%
det_df
# Out:
# {'owner'}
