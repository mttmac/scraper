# %%
import asyncio
import time
from pathlib import Path

import aiohttp
import pandas as pd

DATA_DIR = Path.cwd() / "hdruk_data"
DATA_DIR.mkdir(parents=True, exist_ok=True)

SERVER_ERRORS = (
    aiohttp.ClientConnectionError,
    aiohttp.ClientResponseError,
)

class ErrorCounter:
    def __init__(self) -> None:
        self.count = 0
    
    def count(self):
        self.count += 1
    
    def reset(self):
        self.count = 0
    
    def __str__(self):
        return str(self.count)


err_count = ErrorCounter()


class Logger:
    def __init__(self) -> None:
        self.t0 = time.time()
        self.tl = self.t0

    def __call__(self, msg: str, *args):
        tn = time.time()
        ts = f"{tn - self.t0:9.4f}s"
        if (tn - self.tl) < 0.1:
            ds = "<0.1s"
        else:
            ds = f"{tn - self.tl:4.1f}s"
        self.tl = tn

        msg = f"{ts} ({ds}): {' '.join([msg, *[str(a) for a in args]])}"
        print(msg)


async def fetch(client, url, name, log):
    async with client.get(url) as resp:
        try:
            if resp.status != 200:
                resp.raise_for_status()
            log(f"Read {url}.")
            
            resp_text = await resp.text()
            save_path = DATA_DIR / f"{name}.json"
            save_path.write_text(resp_text)

            return resp_text

        except SERVER_ERRORS:
            err_count.count()
            return None
        

async def fetch_all(client, urls, names, log):
    tasks = []
    for url, name in zip(urls, names):
        task = asyncio.create_task(fetch(client, url, name, log))
        tasks.append(task)
    res = await asyncio.gather(*tasks)
    return res


async def read_json_from_hdruk_api(paths, names, log):
    URL = "https://phenotypes.healthdatagateway.org"
    urls =[f"/api/v1/public/{path}/?format=json" for path in paths]
    
    log(f"Reading {len(urls)} endpoints from {URL}...")

    async with aiohttp.ClientSession(base_url=URL) as client:
        responses = await fetch_all(client, urls, names, log)
    
    log("Finished reading.")
    
    return responses


def convert_responses(names, responses):
    data = {ep: pd.read_json(res) for ep, res in zip(names, responses) if res is not None}

    return data


async def read_hdruk_data(resource, ids = None, endpoint = ""):
    log = Logger()
    if ids is None:
        ids = [""]

    paths = []
    names = []
    data = {}
    for id in ids:
        path = f"{resource}/{id}/{endpoint}".strip("/")
        name = path.replace("/", "_")

        file_path = (DATA_DIR / f"{name}.json")
        if file_path.exists():
            data[name] = pd.read_json(file_path)
        else:
            paths.append(path)
            names.append(name)

    if paths:
        responses = await read_json_from_hdruk_api(paths, names, log)
        data.update(convert_responses(names, responses))
    else:
        log(f"All data scraped for {resource}/{endpoint}")

    return data


async def read_hdruk_lists():
    resources = [
        "phenotypes",
        "concepts",
        "coding-systems",
        "data-sources",
        "tags",
        "collections",
    ]
    data = {}
    for res in resources:
        res_data = await read_hdruk_data(res)
        data.update(res_data)

    return data


async def read_hdruk_data_with_retries(resource, ids = None, endpoint = "", max_retries=100):
    for i in range(1 + max_retries):
        try:
            return await read_hdruk_data(resource, ids, endpoint)
        except SERVER_ERRORS as exc:
            if i < max_retries:
                print(f"Server error: {exc}.")
                print(f"Counted {err_count} GET errors.")
                err_count.reset()

                print("Pausing for 1 minute...")
                time.sleep(60)
            else:
                raise exc

# %%
resources = await read_hdruk_lists()
# Out:
#    0.0992s (<0.1s): All data scraped for phenotypes/
#    0.0393s (<0.1s): All data scraped for concepts/
#    0.0028s (<0.1s): All data scraped for coding-systems/
#    0.0149s (<0.1s): All data scraped for data-sources/
#    0.0028s (<0.1s): All data scraped for tags/
#    0.0026s (<0.1s): All data scraped for collections/

# %%
df = resources["phenotypes"]
print(df.phenotype_id.is_unique)
df.head()
# Out:
# True
#   phenotype_id  version_id          phenotype_name                 type  \
# 0          PH1           2      COVID-19 infection  Disease or Syndrome
# 1          PH2           4                 Anxiety  Disease or Syndrome
# 2          PH3           6              Depression  Disease or Syndrome
# 3          PH4           8               Self Harm  Disease or Syndrome
# 4          PH5        1509  Cardiovascular Disease  Disease or Syndrome
#
#                                               author          owner tags  \
# 0                        BHF CVD COVID UK Consortium  ieuan.scanlon   []
# 1  Matthew J Carr, Sarah Steeg, Roger T Webb, Nav...  ieuan.scanlon   []
# 2  Matthew J Carr, Sarah Steeg, Roger T Webb, Nav...  ieuan.scanlon   []
# 3  Matthew J Carr, Sarah Steeg, Roger T Webb, Nav...  ieuan.scanlon   []
# 4  Ellie Paige, Jessica Barret, David Stevens, Ru...  ieuan.scanlon   []
#
#                                          collections  \
# 0  [{'description': 'BHF Data Science Centre', 'i...
# 1  [{'description': 'Phenotype Library', 'id': 18...
# 2  [{'description': 'Phenotype Library', 'id': 18...
# 3  [{'description': 'Phenotype Library', 'id': 18...
# 4  [{'description': 'Phenotype Library', 'id': 18...
#
#                               clinical_terminologies  \
# 0  [{'name': 'ICD10 codes', 'id': 4}, {'name': 'S...
# 1               [{'name': 'Read codes v2', 'id': 5}]
# 2               [{'name': 'Read codes v2', 'id': 5}]
# 3               [{'name': 'Read codes v2', 'id': 5}]
# 4               [{'name': 'Read codes v2', 'id': 5}]
#
#                                         data_sources  \
# 0  [{'id': 1, 'name': 'GPES Data for Pandemic Pla...
# 1  [{'id': 6, 'name': 'CPRD Aurum', 'url': 'https...
# 2  [{'id': 6, 'name': 'CPRD Aurum', 'url': 'https...
# 3  [{'id': 6, 'name': 'CPRD Aurum', 'url': 'https...
# 4  [{'id': 5, 'name': 'CPRD GOLD', 'url': 'https:...
#
#                                             versions
# 0  [{'version_id': 2, 'version_name': 'COVID-19 i...
# 1  [{'version_id': 4, 'version_name': 'Anxiety', ...
# 2  [{'version_id': 6, 'version_name': 'Depression...
# 3  [{'version_id': 8, 'version_name': 'Self Harm'...
# 4  [{'version_id': 1509, 'version_name': 'Cardiov...

# %%
codes = await read_hdruk_data_with_retries("phenotypes", df.phenotype_id, "export/codes")
# Out:
#    6.9545s ( 7.0s): Reading 37 endpoints from https://phenotypes.healthdatagateway.org...
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# Cell In [1], line 55, in fetch(client, url, name, log)
#      54 if resp.status != 200:
# ---> 55     resp.raise_for_status()
#      56 log(f"Read {url}.")
#
# File ~/venv/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1005, in ClientResponse.raise_for_status(self)
#    1004 self.release()
# -> 1005 raise ClientResponseError(
#    1006     self.request_info,
#    1007     self.history,
#    1008     status=self.status,
#    1009     message=self.reason,
#    1010     headers=self.headers,
#    1011 )
#
# ClientResponseError: 500, message='Internal Server Error', url=URL('https://phenotypes.healthdatagateway.org/api/v1/public/phenotypes/PH1019/export/codes/?format=json')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 codes = await read_hdruk_data_with_retries("phenotypes", df.phenotype_id, "export/codes")
#
# Cell In [1], line 146, in read_hdruk_data_with_retries(resource, ids, endpoint, max_retries)
#     144 for i in range(1 + max_retries):
#     145     try:
# --> 146         return await read_hdruk_data(resource, ids, endpoint)
#     147     except SERVER_ERRORS as exc:
#     148         if i < max_retries:
#
# Cell In [1], line 118, in read_hdruk_data(resource, ids, endpoint)
#     115         names.append(name)
#     117 if paths:
# --> 118     responses = await read_json_from_hdruk_api(paths, names, log)
#     119     data.update(convert_responses(names, responses))
#     120 else:
#
# Cell In [1], line 85, in read_json_from_hdruk_api(paths, names, log)
#      82 log(f"Reading {len(urls)} endpoints from {URL}...")
#      84 async with aiohttp.ClientSession(base_url=URL) as client:
# ---> 85     responses = await fetch_all(client, urls, names, log)
#      87 log("Finished reading.")
#      89 return responses
#
# Cell In [1], line 74, in fetch_all(client, urls, names, log)
#      72     task = asyncio.create_task(fetch(client, url, name, log))
#      73     tasks.append(task)
# ---> 74 res = await asyncio.gather(*tasks)
#      75 return res
#
# Cell In [1], line 65, in fetch(client, url, name, log)
#      62     return resp_text
#      64 except SERVER_ERRORS:
# ---> 65     err_count.count()
#      66     return None
#
# TypeError: 'int' object is not callable

# %%
details = await read_hdruk_data_with_retries("phenotypes", df.phenotype_id, "detail")
# Out:
#    4.5671s ( 4.6s): Reading 167 endpoints from https://phenotypes.healthdatagateway.org...
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# Cell In [1], line 55, in fetch(client, url, name, log)
#      54 if resp.status != 200:
# ---> 55     resp.raise_for_status()
#      56 log(f"Read {url}.")
#
# File ~/venv/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1005, in ClientResponse.raise_for_status(self)
#    1004 self.release()
# -> 1005 raise ClientResponseError(
#    1006     self.request_info,
#    1007     self.history,
#    1008     status=self.status,
#    1009     message=self.reason,
#    1010     headers=self.headers,
#    1011 )
#
# ClientResponseError: 503, message='Service Unavailable', url=URL('https://phenotypes.healthdatagateway.org/api/v1/public/phenotypes/PH912/detail/?format=json')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 details = await read_hdruk_data_with_retries("phenotypes", df.phenotype_id, "detail")
#
# Cell In [1], line 146, in read_hdruk_data_with_retries(resource, ids, endpoint, max_retries)
#     144 for i in range(1 + max_retries):
#     145     try:
# --> 146         return await read_hdruk_data(resource, ids, endpoint)
#     147     except SERVER_ERRORS as exc:
#     148         if i < max_retries:
#
# Cell In [1], line 118, in read_hdruk_data(resource, ids, endpoint)
#     115         names.append(name)
#     117 if paths:
# --> 118     responses = await read_json_from_hdruk_api(paths, names, log)
#     119     data.update(convert_responses(names, responses))
#     120 else:
#
# Cell In [1], line 85, in read_json_from_hdruk_api(paths, names, log)
#      82 log(f"Reading {len(urls)} endpoints from {URL}...")
#      84 async with aiohttp.ClientSession(base_url=URL) as client:
# ---> 85     responses = await fetch_all(client, urls, names, log)
#      87 log("Finished reading.")
#      89 return responses
#
# Cell In [1], line 74, in fetch_all(client, urls, names, log)
#      72     task = asyncio.create_task(fetch(client, url, name, log))
#      73     tasks.append(task)
# ---> 74 res = await asyncio.gather(*tasks)
#      75 return res
#
# Cell In [1], line 65, in fetch(client, url, name, log)
#      62     return resp_text
#      64 except SERVER_ERRORS:
# ---> 65     err_count.count()
#      66     return None
#
# TypeError: 'int' object is not callable

# %%
# Not needed right now
# concepts = await read_hdruk_data("concepts", resources["concepts"].concept_id, "detail")
# Out:
#    0.0000s (<0.1s): Reading 2219 endpoints from https://phenotypes.healthdatagateway.org...
#    2.7020s ( 2.7s): Read /api/v1/public/concepts/C750/detail/?format=json.
#    2.7057s (<0.1s): Read /api/v1/public/concepts/C741/detail/?format=json.
#    2.7757s (<0.1s): Read /api/v1/public/concepts/C732/detail/?format=json.
#    2.8005s (<0.1s): Read /api/v1/public/concepts/C737/detail/?format=json.
#    2.8738s (<0.1s): Read /api/v1/public/concepts/C714/detail/?format=json.
#    2.8751s (<0.1s): Read /api/v1/public/concepts/C719/detail/?format=json.
#    2.9179s (<0.1s): Read /api/v1/public/concepts/C745/detail/?format=json.
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# /Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> concepts = await read_hdruk_data("concepts", con_df.concept_id, "detail")
#
# /Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb Cell 7 in read_hdruk_data(resource, ids, endpoint)
#     <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=101'>102</a>         names.append(name)
#     <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=103'>104</a> if paths:
# --> <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=104'>105</a>     responses = await read_json_from_hdruk_api(paths, names)
#     <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=105'>106</a>     data.update(convert_responses(names, responses))
#     <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=107'>108</a> return data
#
# /Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb Cell 7 in read_json_from_hdruk_api(paths, names)
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=69'>70</a> log(f"Reading {len(urls)} endpoints from {URL}...")
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=71'>72</a> async with aiohttp.ClientSession(base_url=URL) as client:
# ---> <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=72'>73</a>     responses = await fetch_all(client, urls, names, log)
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=74'>75</a> log("Finished reading.")
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=76'>77</a> return responses
#
# /Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb Cell 7 in fetch_all(client, urls, names, log)
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=58'>59</a>     task = asyncio.create_task(fetch(client, url, name, log))
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=59'>60</a>     tasks.append(task)
# ---> <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=60'>61</a> res = await asyncio.gather(*tasks)
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=61'>62</a> return res
#
# /Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb Cell 7 in fetch(client, url, name, log)
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=50'>51</a>     time.sleep(5)  # pause
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=51'>52</a> else:
# ---> <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=52'>53</a>     raise exc
#
# /Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb Cell 7 in fetch(client, url, name, log)
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=36'>37</a> async with client.get(url) as resp:
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=37'>38</a>     if resp.status != 200:
# ---> <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=38'>39</a>         resp.raise_for_status()
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=39'>40</a>     log(f"Read {url}.")
#      <a href='vscode-notebook-cell:/Users/mattmacdonald/Local/scraper/hdruk_phenotypes.ipynb#W6sZmlsZQ%3D%3D?line=41'>42</a>     resp_text = await resp.text()
#
# File ~/opt/anaconda3/envs/dev/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1005, in ClientResponse.raise_for_status(self)
#    1003 assert self.reason is not None
#    1004 self.release()
# -> 1005 raise ClientResponseError(
#    1006     self.request_info,
#    1007     self.history,
#    1008     status=self.status,
#    1009     message=self.reason,
#    1010     headers=self.headers,
#    1011 )
#
# ClientResponseError: 502, message='Proxy Error', url=URL('https://phenotypes.healthdatagateway.org/api/v1/public/concepts/C794/detail/?format=json')
